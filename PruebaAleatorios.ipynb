# %% [markdown]
# ### Prueba
# ### A traves de la misma api generar una semilla diferente.
# ### Encontrar el numero de iteraciones hasta que se repita uno de sus datos.

# %%
import matplotlib.pyplot as pp

# %%
datos = []
similares = []
semilla = 2132
for ite in range(1, 100):
    i = 0
    a = 3
    b = 5
    m = 17
    tmp = 0
    ui = 0
    if(iter == 1):
        xn = semilla
    else:
        tmp = ui
    while True:
        xn = (a * (ui) + b)%m
        ui = xn/m
        tmp = ui
        if(ui in datos):
            print('Iteracion:', ite, ui)
            similares.append(ui)
            break
        datos.append(ui)
# Out:
# Iteracion: 1 0.35714285714285715
# Iteracion: 2 0.29411764705882354
# Iteracion: 3 0.29411764705882354
# Iteracion: 4 0.29411764705882354
# Iteracion: 5 0.29411764705882354
# Iteracion: 6 0.29411764705882354
# Iteracion: 7 0.29411764705882354
# Iteracion: 8 0.29411764705882354
# Iteracion: 9 0.29411764705882354
# Iteracion: 10 0.29411764705882354
# Iteracion: 11 0.29411764705882354
# Iteracion: 12 0.29411764705882354
# Iteracion: 13 0.29411764705882354
# Iteracion: 14 0.29411764705882354
# Iteracion: 15 0.29411764705882354
# Iteracion: 16 0.29411764705882354
# Iteracion: 17 0.29411764705882354
# Iteracion: 18 0.29411764705882354
# Iteracion: 19 0.29411764705882354
# Iteracion: 20 0.29411764705882354
# Iteracion: 21 0.29411764705882354
# Iteracion: 22 0.29411764705882354
# Iteracion: 23 0.29411764705882354
# Iteracion: 24 0.29411764705882354
# Iteracion: 25 0.29411764705882354
# Iteracion: 26 0.29411764705882354
# Iteracion: 27 0.29411764705882354
# Iteracion: 28 0.29411764705882354
# ...

# %%
pp.hist(similares, bins=10, edgecolor = 'black',linewidth=1)
pp.show()

# %%
data = []
similars = []
for ite in range(1, 101):
    semilla = 8370
    digitos = 4
    ui = 0
    while(True):
        if (ui > 0):
            xn = ui
        else:
            xn = semilla
        cuadrado = str(xn**2)
        lon = len(cuadrado)
        tem = ""
        for x in range(int(lon/2)-2, int(lon/2)):
            tem += cuadrado[x]
        for x in range(int(lon/2), int(lon/2)+2):
            tem += cuadrado[x]
        ui = int(tem)
        if((ui/10000) in data):
            print('Iteracion:', ite, (ui/10000))
            similars.append(ui/10000)
            break
        data.append((ui/10000))
# Out:
# Iteracion: 1 0.81
# Iteracion: 2 0.0569
# Iteracion: 3 0.0569
# Iteracion: 4 0.0569
# Iteracion: 5 0.0569
# Iteracion: 6 0.0569
# Iteracion: 7 0.0569
# Iteracion: 8 0.0569
# Iteracion: 9 0.0569
# Iteracion: 10 0.0569
# Iteracion: 11 0.0569
# Iteracion: 12 0.0569
# Iteracion: 13 0.0569
# Iteracion: 14 0.0569
# Iteracion: 15 0.0569
# Iteracion: 16 0.0569
# Iteracion: 17 0.0569
# Iteracion: 18 0.0569
# Iteracion: 19 0.0569
# Iteracion: 20 0.0569
# Iteracion: 21 0.0569
# Iteracion: 22 0.0569
# Iteracion: 23 0.0569
# Iteracion: 24 0.0569
# Iteracion: 25 0.0569
# Iteracion: 26 0.0569
# Iteracion: 27 0.0569
# Iteracion: 28 0.0569
# Iteracion: 29 0.0569
# Iteracion: 30 0.0569
# Iteracion: 31 0.0569
# Iteracion: 32 0.0569
# Iteracion: 33 0.0569
# Iteracion: 34 0.0569
# Iteracion: 35 0.0569
# Iteracion: 36 0.0569
# Iteracion: 37 0.0569
# Iteracion: 38 0.0569
# Iteracion: 39 0.0569
# Iteracion: 40 0.0569
# Iteracion: 41 0.0569
# Iteracion: 42 0.0569
# Iteracion: 43 0.0569
# ...

# %%
pp.hist(similars, bins=10, edgecolor = 'black',linewidth=1)
pp.show()

# %% [markdown]
# ## Recomendaciones y Conclusiones
# Es recomendable dar como semillas iniciales las que nos recomienda la teoria, esto va a depender para cada lenguaje de programación.
#
# Por lo tanto dependera mucho de los parametros iniciales para que por cada iteracion exista por lo menos una repetición, por este motivo para mi criterio personal es mucho mejor hacer uso del metodo de congruencia lineal.
